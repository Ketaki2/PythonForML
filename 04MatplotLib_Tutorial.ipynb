# %% [markdown]
# ## MatplotLib
# It is a plotting library in Python and it's numerical mathematical extension is NumPy(NumPy is the base library).It provides an object oriented path for embedding plots into applications.
# Some of the major Pros of Matplotlib are:
# - Generally easy to get started for simple plots
# - Support for custom labels and texts
# - Great control of every element in a figure
# - High-quality output in many formats
# - Very customizable in general

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
## Displays the graphs without having to write plt.show()

# %%
# %matplotlib inline

# %%
x= np.arange(0,10)
y=np.arange(11,21)

# %%
## plotting using matplotlib

# %%
#Plot scatter
plt.scatter(x,y,c='b')
plt.title('Graph')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.savefig('Graph.png') #Picture uploaded in the same repository as this file
# plt.show() not required because of matplotlib%inline

# %%
# using plot-> gives straight line
y=x*x
plt.plot(x,y,'r--')

# %%
plt.plot(x,y,'r*-')

# %%
plt.plot(x,y,'ro') # Colour and pattern specified in the third parameter

# %%
plt.plot(x,y,'r',linestyle='dashed',linewidth=2, markersize=20) # Colour and pattern specified in the third parameter
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Graph in 2D')
# Out:
# Text(0.5,1,'Graph in 2D')

# %%
plt.subplot(2,2,1)
plt.plot(x,y,'b')
plt.subplot(2,2,2)
plt.plot(x,y,'r')
plt.subplot(2,2,3)
plt.plot(x,y,'g')
plt.subplot(2,2,4)
plt.plot(x,y,'c')

# %%
x=np.arange(1,11)
y=3*x+5
plt.plot(x,y,'r*--')

# %%
np.pi
# Out:
# 3.141592653589793

# %%
x=np.arange(0,4*np.pi,0.1)
y=np.sin(x)
plt2=plt.plot(x,y,'r*--')

# %% [markdown]
# ## Complex Curves

# %%
#Subplot()
# Compute the x and y coordinates for points on sine and cosine curves 
x = np.arange(0, 5 * np.pi, 0.1) 
y_sin = np.sin(x) 
y_cos = np.cos(x)  
   
# Set up a subplot grid that has height 2 and width 1, 
# and set the first such subplot as active. 
plt.subplot(2, 1, 1)
   
# Make the first plot 
plt.plot(x, y_sin,'r--') 
plt.title('Sine')  
   
# Set the second subplot as active, and make the second plot. 
plt.subplot(2, 1, 2) 
plt.plot(x, y_cos,'g--') 
plt.title('Cosine')  
plt.show()

# %% [markdown]
# ## Bar Plot

# %%
x = [2,8,10] 
y = [11,16,9]  

x2 = [3,9,11] 
y2 = [6,15,7] 
plt.bar(x, y) 
plt.bar(x2, y2, color = 'g') 
plt.title('Bar graph') 
plt.ylabel('Y axis') 
plt.xlabel('X axis')  

plt.show()

# %% [markdown]
# ## Histograms

# %%
a = np.array([22,87,5,43,56,73,55,54,11,20,51,5,79,31,27]) 
plt.hist(a,bins=20) 
plt.title("histogram") 
plt.show()

# %% [markdown]
# ## BoxPlot

# %%
data=[np.random.normal(0,std,100) for std in range(1,4)]

# %%
plt.boxplot(data,vert=True,patch_artist=True)
plt.show()

# %%
data
# Out:
# [array([ 0.84130224,  0.37252215, -0.56978599, -0.64329521,  0.8403517 ,
#          0.79040616, -0.28522501,  1.29017294,  1.20396496, -1.53387656,
#         -0.42966696,  0.14835177, -0.1570267 ,  1.36584622,  0.54367823,
#          1.62663926, -0.59315171,  1.17326569,  1.2537213 ,  0.63963767,
#         -1.38447938, -0.54171081, -0.39581058, -1.48256046, -0.43009028,
#         -0.58554786, -0.80144911, -0.85840472, -0.39245248, -0.64891503,
#          1.3634412 , -1.13793463, -1.99517586,  1.43414649, -1.61368632,
#          1.4154115 ,  0.24710758, -0.50742717,  0.0674824 ,  0.54227392,
#         -1.14501758, -0.38201698, -1.7340046 ,  0.2135521 , -1.46835674,
#         -1.18915465, -1.63876717, -0.22114023,  0.03175637, -0.13985665,
#          0.46629657, -0.09993652,  2.33553326,  0.35313478, -1.31179248,
#         -0.34804347, -2.14944398, -1.15503152,  0.10953653, -0.76917898,
#          0.50850894, -0.94278085,  0.02804093,  1.24023316, -0.8472307 ,
# ...

# %% [markdown]
# ## Pie Chart

# %%
# Data to plot
labels = 'Python', 'C++', 'Ruby', 'Java'
sizes = [215, 130, 245, 210]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0.5, 0, 0, 0)  # explode 1st slice to view it farther from the other slices

# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True) # Autopct->show the percentages in 1.1 float format
plt.axis('equal')
plt.show()
